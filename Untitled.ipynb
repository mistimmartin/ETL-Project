# %%
import pandas as pd
from sqlalchemy import create_engine
import psycopg2
# from config import password

# %%
calendar_df = pd.read_csv("Resources/calendar.csv")
calendar_df = calendar_df[calendar_df.available != 'f']
calendar_df
# Out:
#          listing_id        date available   price
# 0            241032  2016-01-04         t  $85.00
# 1            241032  2016-01-05         t  $85.00
# 9            241032  2016-01-13         t  $85.00
# 10           241032  2016-01-14         t  $85.00
# 14           241032  2016-01-18         t  $85.00
# ...             ...         ...       ...     ...
# 1393207    10208623  2016-01-06         t  $87.00
# 1393208    10208623  2016-01-07         t  $87.00
# 1393211    10208623  2016-01-10         t  $87.00
# 1393212    10208623  2016-01-11         t  $87.00
# 1393213    10208623  2016-01-12         t  $87.00
#
# [934542 rows x 4 columns]

# %%
listings_df = pd.read_csv("Resources/listings.csv")
listings_df.head()
# Out:
#         id                           listing_url       scrape_id last_scraped  \
# 0   241032   https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
# 1   953595   https://www.airbnb.com/rooms/953595  20160104002432   2016-01-04
# 2  3308979  https://www.airbnb.com/rooms/3308979  20160104002432   2016-01-04
# 3  7421966  https://www.airbnb.com/rooms/7421966  20160104002432   2016-01-04
# 4   278830   https://www.airbnb.com/rooms/278830  20160104002432   2016-01-04
#
#                                   name  \
# 0         Stylish Queen Anne Apartment
# 1   Bright & Airy Queen Anne Apartment
# 2  New Modern House-Amazing water view
# 3                   Queen Anne Chateau
# 4       Charming craftsman 3 bdm house
#
#                                              summary  \
# 0                                                NaN
# 1  Chemically sensitive? We've removed the irrita...
# 2  New modern house built in 2013.  Spectacular s...
# ...

# %%
reviews_df = pd.read_csv("Resources/reviews.csv")
reviews_df.head()
# Out:
#    listing_id        id        date  reviewer_id reviewer_name  \
# 0     7202016  38917982  2015-07-19     28943674        Bianca
# 1     7202016  39087409  2015-07-20     32440555         Frank
# 2     7202016  39820030  2015-07-26     37722850           Ian
# 3     7202016  40813543  2015-08-02     33671805        George
# 4     7202016  41986501  2015-08-10     34959538          Ming
#
#                                             comments
# 0  Cute and cozy place. Perfect location to every...
# 1  Kelly has a great room in a very central locat...
# 2  Very spacious apartment, and in a great neighb...
# 3  Close to Seattle Center and all it has to offe...
# 4  Kelly was a great host and very accommodating ...

# %%
calendar_df_clean= calendar_df[["listing_id","date","price"]].copy()
calendar_df_clean.count()
# Out:
# listing_id    934542
# date          934542
# price         934542
# dtype: int64

# %%
listings_df_clean=listings_df[["id","name","neighbourhood_cleansed","price","number_of_reviews","review_scores_rating"]].copy()
listings_df_clean.head()
# Out:
#         id                                 name neighbourhood_cleansed  \
# 0   241032         Stylish Queen Anne Apartment        West Queen Anne
# 1   953595   Bright & Airy Queen Anne Apartment        West Queen Anne
# 2  3308979  New Modern House-Amazing water view        West Queen Anne
# 3  7421966                   Queen Anne Chateau        West Queen Anne
# 4   278830       Charming craftsman 3 bdm house        West Queen Anne
#
#      price  number_of_reviews  review_scores_rating
# 0   $85.00                207                  95.0
# 1  $150.00                 43                  96.0
# 2  $975.00                 20                  97.0
# 3  $100.00                  0                   NaN
# 4  $450.00                 38                  92.0

# %%
reviews_df_clean= reviews_df[["listing_id","comments"]].copy()
reviews_df_clean.head()
# Out:
#    listing_id                                           comments
# 0     7202016  Cute and cozy place. Perfect location to every...
# 1     7202016  Kelly has a great room in a very central locat...
# 2     7202016  Very spacious apartment, and in a great neighb...
# 3     7202016  Close to Seattle Center and all it has to offe...
# 4     7202016  Kelly was a great host and very accommodating ...

# %%
connection_string = "postgres:Sunshine1@localhost:5432/seattle_airbnb"
engine = create_engine(f'postgresql://{connection_string}')

# %%
engine.table_names()
# Out:
# ['listings', 'reviews']

# %%
calendar_df_clean.to_sql(name='calendar', con=engine, if_exists='append', index=False)

# %%
pd.read_sql_query('select * from calendar', con=engine).head()

# %%
listings_df_clean.to_sql(name='listings',con=engine,if_exists='append',index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-6cbca3c5fa9f> in <module>
# ----> 1 listings_df_clean.to_sql(name='listings',con=engine,if_exists='append',index=False)
#
# NameError: name 'listings_df_clean' is not defined

# %%
pd.read_sql_query('select * from listings',con=engine).head()
# Out:
#         id                                 name neighbourhood_cleansed  \
# 0   241032         Stylish Queen Anne Apartment        West Queen Anne
# 1   953595   Bright & Airy Queen Anne Apartment        West Queen Anne
# 2  3308979  New Modern House-Amazing water view        West Queen Anne
# 3  7421966                   Queen Anne Chateau        West Queen Anne
# 4   278830       Charming craftsman 3 bdm house        West Queen Anne
#
#      price  number_of_reviews  review_scores_rating
# 0   $85.00                207                  95.0
# 1  $150.00                 43                  96.0
# 2  $975.00                 20                  97.0
# 3  $100.00                  0                   NaN
# 4  $450.00                 38                  92.0

# %%
reviews_df_clean.to_sql(name='reviews',con=engine,if_exists='append',index=False)

# %%
pd.read_sql_query('select * from reviews',con=engine).head()
# Out:
#    listing_id                                           comments
# 0     7202016  Cute and cozy place. Perfect location to every...
# 1     7202016  Kelly has a great room in a very central locat...
# 2     7202016  Very spacious apartment, and in a great neighb...
# 3     7202016  Close to Seattle Center and all it has to offe...
# 4     7202016  Kelly was a great host and very accommodating ...

# %%
combined_df = pd.read_sql_query('select c.listing_id, c.price, l.name, l.number_of_reviews, l.review_scores_rating, r.comments from calendar as c\
                                join listings as l\
                                on c.listing_id = l.id\
                                join reviews as r\
                                on c.listing_id = r.listing_id', con=engine)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1248                     self.dialect.do_execute(
# -> 1249                         cursor, statement, parameters, context
#    1250                     )
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     579     def do_execute(self, cursor, statement, parameters, context=None):
# --> 580         cursor.execute(statement, parameters)
#     581
#
# OperationalError: server closed the connection unexpectedly
# 	This probably means the server terminated abnormally
# 	before or while processing the request.
#
#
# The above exception was the direct cause of the following exception:
#
# ...
